# %%
import os

# %%
root = '/Volumes/Tuneage/MajorTuneage'

# %%
music_extensions = ['.mp3', '.m4a', '.aac']
music_files = []

def is_music_file(f):
    return os.path.splitext(f)[1] in music_extensions

def visit_dirs(arg, dirname, names):
    music_files = filter(is_music_file,names)
    music_files
    print("Found {} music files in {}".format(len(music_files), dirname))

# %%
os.path.walk(root, visit_dirs, {'arg': 'bungus'})
# Out:
# Found 0 music files in /Volumes/Tuneage/MajorTuneage
# Found 0 music files in /Volumes/Tuneage/MajorTuneage/disk0
# Found 10 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3
# Found 0 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles
# Found 1 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Alabama
# Found 2 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Ben Folds Five
# Found 1 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Bobby Bare
# Found 3 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Bon Jovi
# Found 2 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Bonnie Raitt
# Found 1 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Buddy Guy
# Found 1 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Buddy Holly
# Found 3 music files in /Volumes/Tuneage/MajorTuneage/disk0/mp3/0Singles/Carlos Santana
# ...
